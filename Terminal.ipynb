# %% [markdown]
# # Terminal

# %% [markdown]
# Мы находимся в среде разработки **Jupyter notebook**, которая запущена на компе с системой **Linux** (Ubuntu)

# %% [markdown]
# Эта среда предназначена для напиания кода на языке программирования **Python**.

# %% [markdown]
# ## Создаем свой notebook
#
# откройте в новой вкладке или в новом окне ссылку: http://89.208.33.211:9999/
#
# потом создайте свой файл, нажав на кнопку **New** > **Python 3**
# ![image-2.png](attachment:image-2.png)
#
# потом он откроется, вверху жмем на надпись **Untitled**, переименовываем под свое имя, как тут:
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## как в нем работать?
#
# пишем команду, нажимаем **shift+Enter** - она выполняется

# %%
2+2  # Это Python, оно как и почти все языки программирования может считать
# Out:
# 4

# %% [markdown]
# Выше введена **python** команда, а в Out мы видим результат ее выполнения.

# %% [markdown]
# Но до **python** мы доберемся позже. Сейчас нам нужен **terminal** и **bash**.

# %% [markdown]
# **bash** - это та штука, которая может управлять компом через свои команды. Это командный интерпритатор.
#
# **sh** - это shell (оболочка).
#
# Можно сказать, что **bash** - это тоже самое, что и **sh**, только более продвинутый и новый, с бОльшими возможнотями.

# %% [markdown]
# ### Команды терминала
# Для выполенний команд терминала в **jupyter** нужно впереди писать ! - восклицательный знак

# %%
# !pwd
# Out:
# /home/test/jupyter/Материалы

# %% [markdown]
# **pwd** - *print working directory* (напечатать рабочую директорию). то есть вывести текущую папку, в которой мы находимся
#
# вывелось:
#
# **/home/test/jupyter/Материалы**

# %%
# !ls
# Out:
# Terminal.ipynb

# %% [markdown]
# Содержание текущей папки

# %%
# !ls --help
# Out:
# Usage: ls [OPTION]... [FILE]...
# List information about the FILEs (the current directory by default).
# Sort entries alphabetically if none of -cftuvSUX nor --sort is specified.
#
# Mandatory arguments to long options are mandatory for short options too.
#   -a, --all                  do not ignore entries starting with .
#   -A, --almost-all           do not list implied . and ..
#       --author               with -l, print the author of each file
#   -b, --escape               print C-style escapes for nongraphic characters
#       --block-size=SIZE      with -l, scale sizes by SIZE when printing them;
#                                e.g., '--block-size=M'; see SIZE format below
#   -B, --ignore-backups       do not list implied entries ending with ~
#   -c                         with -lt: sort by, and show, ctime (time of last
#                                modification of file status information);
#                                with -l: show ctime and sort by name;
#                                otherwise: sort by ctime, newest first
#   -C                         list entries by columns
#       --color[=WHEN]         colorize the output; WHEN can be 'always' (default
#                                if omitted), 'auto', or 'never'; more info below
#   -d, --directory            list directories themselves, not their contents
#   -D, --dired                generate output designed for Emacs' dired mode
#   -f                         do not sort, enable -aU, disable -ls --color
#   -F, --classify             append indicator (one of */=>@|) to entries
#       --file-type            likewise, except do not append '*'
#       --format=WORD          across -x, commas -m, horizontal -x, long -l,
#                                single-column -1, verbose -l, vertical -C
#       --full-time            like -l --time-style=full-iso
#   -g                         like -l, but do not list owner
#       --group-directories-first
#                              group directories before files;
#                                can be augmented with a --sort option, but any
#                                use of --sort=none (-U) disables grouping
#   -G, --no-group             in a long listing, don't print group names
#   -h, --human-readable       with -l and -s, print sizes like 1K 234M 2G etc.
#       --si                   likewise, but use powers of 1000 not 1024
#   -H, --dereference-command-line
#                              follow symbolic links listed on the command line
#       --dereference-command-line-symlink-to-dir
#                              follow each command line symbolic link
#                                that points to a directory
#       --hide=PATTERN         do not list implied entries matching shell PATTERN
#                                (overridden by -a or -A)
#       --hyperlink[=WHEN]     hyperlink file names; WHEN can be 'always'
#                                (default if omitted), 'auto', or 'never'
#       --indicator-style=WORD  append indicator with style WORD to entry names:
#                                none (default), slash (-p),
#                                file-type (--file-type), classify (-F)
#   -i, --inode                print the index number of each file
#   -I, --ignore=PATTERN       do not list implied entries matching shell PATTERN
#   -k, --kibibytes            default to 1024-byte blocks for disk usage;
#                                used only with -s and per directory totals
#   -l                         use a long listing format
#   -L, --dereference          when showing file information for a symbolic
#                                link, show information for the file the link
#                                references rather than for the link itself
#   -m                         fill width with a comma separated list of entries
#   -n, --numeric-uid-gid      like -l, but list numeric user and group IDs
#   -N, --literal              print entry names without quoting
#   -o                         like -l, but do not list group information
#   -p, --indicator-style=slash
#                              append / indicator to directories
#   -q, --hide-control-chars   print ? instead of nongraphic characters
#       --show-control-chars   show nongraphic characters as-is (the default,
#                                unless program is 'ls' and output is a terminal)
#   -Q, --quote-name           enclose entry names in double quotes
#       --quoting-style=WORD   use quoting style WORD for entry names:
#                                literal, locale, shell, shell-always,
#                                shell-escape, shell-escape-always, c, escape
#                                (overrides QUOTING_STYLE environment variable)
#   -r, --reverse              reverse order while sorting
#   -R, --recursive            list subdirectories recursively
#   -s, --size                 print the allocated size of each file, in blocks
#   -S                         sort by file size, largest first
#       --sort=WORD            sort by WORD instead of name: none (-U), size (-S),
#                                time (-t), version (-v), extension (-X)
#       --time=WORD            with -l, show time as WORD instead of default
#                                modification time: atime or access or use (-u);
#                                ctime or status (-c); also use specified time
#                                as sort key if --sort=time (newest first)
#       --time-style=TIME_STYLE  time/date format with -l; see TIME_STYLE below
#   -t                         sort by modification time, newest first
#   -T, --tabsize=COLS         assume tab stops at each COLS instead of 8
#   -u                         with -lt: sort by, and show, access time;
#                                with -l: show access time and sort by name;
#                                otherwise: sort by access time, newest first
#   -U                         do not sort; list entries in directory order
#   -v                         natural sort of (version) numbers within text
#   -w, --width=COLS           set output width to COLS.  0 means no limit
#   -x                         list entries by lines instead of by columns
#   -X                         sort alphabetically by entry extension
#   -Z, --context              print any security context of each file
#   -1                         list one file per line.  Avoid '\n' with -q or -b
#       --help     display this help and exit
#       --version  output version information and exit
#
# The SIZE argument is an integer and optional unit (example: 10K is 10*1024).
# Units are K,M,G,T,P,E,Z,Y (powers of 1024) or KB,MB,... (powers of 1000).
#
# The TIME_STYLE argument can be full-iso, long-iso, iso, locale, or +FORMAT.
# FORMAT is interpreted like in date(1).  If FORMAT is FORMAT1<newline>FORMAT2,
# then FORMAT1 applies to non-recent files and FORMAT2 to recent files.
# TIME_STYLE prefixed with 'posix-' takes effect only outside the POSIX locale.
# Also the TIME_STYLE environment variable sets the default style to use.
#
# Using color to distinguish file types is disabled both by default and
# with --color=never.  With --color=auto, ls emits color codes only when
# standard output is connected to a terminal.  The LS_COLORS environment
# variable can change the settings.  Use the dircolors command to set it.
#
# Exit status:
#  0  if OK,
#  1  if minor problems (e.g., cannot access subdirectory),
#  2  if serious trouble (e.g., cannot access command-line argument).
#
# GNU coreutils online help: <https://www.gnu.org/software/coreutils/>
# Full documentation at: <https://www.gnu.org/software/coreutils/ls>
# or available locally via: info '(coreutils) ls invocation'

# %% [markdown]
# Попросили хелп по этой команде, можем почитать, как ей пользоваться

# %%
# !man ls
# Out:
# LS(1)                            User Commands                           LS(1)
#
# E
#        ls - list directory contents
#
# S
# E]...
#
# N
#        List  information  about  the FILEs (the current directory by default).
# t  is  speci‐
#        fied.
#
#        Mandatory  arguments  to  long  options are mandatory for short options
#        too.
#
# l
#               do not ignore entries starting with .
#
# l
#               do not list implied . and ..
#
# r
# l, print the author of each file
#
# e
#               print C-style escapes for nongraphic characters
#
# E
# l,  scale  sizes  by  SIZE  when  printing  them;   e.g.,
#               '--block-size=M'; see SIZE format below
#
# s
#               do not list implied entries ending with ~
#
# t: sort by, and show, ctime (time of last modification of
# l: show ctime and sort by  name;
#               otherwise: sort by ctime, newest first
#
# C     list entries by columns
#
# N]
#               colorize  the output; WHEN can be 'always' (default if omitted),
#               'auto', or 'never'; more info below
#
# y
#               list directories themselves, not their contents
#
# d
#               generate output designed for Emacs' dired mode
#
# r
#
# y
#               append indicator (one of */=>@|) to entries
#
# e
#               likewise, except do not append '*'
#
# D
# 1,
# C
#
# e
# o
#
# l, but do not list owner
#
# t
#               group directories before files;
#
# t  option,  but  any  use  of
# U) disables grouping
#
# p
#               in a long listing, don't print group names
#
# e
# s, print sizes like 1K 234M 2G etc.
#
# i   likewise, but use powers of 1000 not 1024
#
# e
#               follow symbolic links listed on the command line
#
# r
#               follow each command line symbolic link
#
#               that points to a directory
#
# N
#               do not list implied entries matching shell  PATTERN  (overridden
# A)
#
# N]
#               hyperlink file names; WHEN can be 'always' (default if omitted),
#               'auto', or 'never'
#
# D
#               append indicator with style WORD to entry names: none (default),
# F)
#
# e
#               print the index number of each file
#
# N
#               do not list implied entries matching shell PATTERN
#
# s
# s
#               and per directory totals
#
# l     use a long listing format
#
# e
#               when showing file information for a symbolic link, show informa‐
#               tion  for  the file the link references rather than for the link
#               itself
#
# m     fill width with a comma separated list of entries
#
# d
# l, but list numeric user and group IDs
#
# l
#               print entry names without quoting
#
# l, but do not list group information
#
# h
#               append / indicator to directories
#
# s
#               print ? instead of nongraphic characters
#
# s
#               show nongraphic characters as-is (the default, unless program is
#               'ls' and output is a terminal)
#
# e
#               enclose entry names in double quotes
#
# D
#               use  quoting style WORD for entry names: literal, locale, shell,
#               shell-always,  shell-escape,  shell-escape-always,   c,   escape
#               (overrides QUOTING_STYLE environment variable)
#
# e
#               reverse order while sorting
#
# e
#               list subdirectories recursively
#
# e
#               print the allocated size of each file, in blocks
#
# S     sort by file size, largest first
#
# D
# t),
# X)
#
# D
# l, show time as WORD instead of default modification time:
# c); also use
# e (newest first)
#
# E
# l; see TIME_STYLE below
#
# t     sort by modification time, newest first
#
# S
#               assume tab stops at each COLS instead of 8
#
# l:  show  access
#               time  and  sort  by name; otherwise: sort by access time, newest
#               first
#
# U     do not sort; list entries in directory order
#
# v     natural sort of (version) numbers within text
#
# S
#               set output width to COLS.  0 means no limit
#
# x     list entries by lines instead of by columns
#
# X     sort alphabetically by entry extension
#
# t
#               print any security context of each file
#
# b
#
# p display this help and exit
#
# n
#               output version information and exit
#
#        The SIZE argument is an integer and  optional  unit  (example:  10K  is
#        10*1024).   Units  are  K,M,G,T,P,E,Z,Y  (powers  of 1024) or KB,MB,...
#        (powers of 1000).
#
#        The TIME_STYLE argument can be  full-iso,  long-iso,  iso,  locale,  or
#        +FORMAT.   FORMAT  is  interpreted  like in date(1).  If FORMAT is FOR‐
#        MAT1<newline>FORMAT2, then FORMAT1 applies to non-recent files and FOR‐
#        MAT2  to  recent files.  TIME_STYLE prefixed with 'posix-' takes effect
#        only outside the POSIX locale.  Also the TIME_STYLE  environment  vari‐
#        able sets the default style to use.
#
#        Using  color  to distinguish file types is disabled both by default and
# o, ls emits color codes only  when
#        standard  output is connected to a terminal.  The LS_COLORS environment
#        variable can change the settings.  Use the dircolors command to set it.
#
# :
#        0      if OK,
#
#        1      if minor problems (e.g., cannot access subdirectory),
#
#        2      if serious trouble (e.g., cannot access command-line argument).
#
# R
#        Written by Richard M. Stallman and David MacKenzie.
#
# S
#        GNU coreutils online help: <https://www.gnu.org/software/coreutils/>
#        Report ls translation bugs to <https://translationproject.org/team/>
#
# T
#        Copyright © 2018 Free Software Foundation, Inc.   License  GPLv3+:  GNU
#        GPL version 3 or later <https://gnu.org/licenses/gpl.html>.
#        This  is  free  software:  you  are free to change and redistribute it.
#        There is NO WARRANTY, to the extent permitted by law.
#
# O
#        Full documentation at: <https://www.gnu.org/software/coreutils/ls>
#        or available locally via: info '(coreutils) ls invocation'
#
# GNU coreutils 8.30              September 2019                           LS(1)

# %% [markdown]
# почти такой же help. man - manual (руководство)

# %%
# !mkdir new_dir

# %%
# !ls
# Out:
# new_dir  Terminal.ipynb

# %% [markdown]
# создали новую папку, убедились, что она появилась

# %%
# !touch new_dir/new_file

# %%
# !ls new_dir
# Out:
# new_file

# %% [markdown]
# создали новый файл (new_file) в папке new_dir, убедились, что он там появился

# %%
# !ls -l
# Out:
# total 32
# drwxrwxr-x 2 test test  4096 Sep 14 16:46 new_dir
# -rw-rw-r-- 1 test test 28171 Sep 14 16:46 Terminal.ipynb

# %%
# !ls -l new_dir
# Out:
# total 0
# -rw-rw-r-- 1 test test 0 Sep 14 16:46 new_file

# %% [markdown]
# вывели содержание папок с ключем -l, который выводит в формате листа

# %%
# !ls -la
# Out:
# total 48
# drwxrwxr-x 4 test test  4096 Sep 14 16:48 .
# drwxrwxr-x 6 test test  4096 Sep 14 14:56 ..
# drwxrwxr-x 2 test test  4096 Sep 14 14:59 .ipynb_checkpoints
# drwxrwxr-x 2 test test  4096 Sep 14 16:46 new_dir
# -rw-rw-r-- 1 test test 29639 Sep 14 16:48 Terminal.ipynb

# %% [markdown]
# с ключем -a видим еще и скрытые файлы

# %% [markdown]
# ## напишем bash скрипт

# %% [markdown]
# для начала научимся писать в файл и читать файл

# %%
# !cat new_dir/new_file

# %% [markdown]
# В файле пусто, потом что мы его недавно создали

# %%
# !echo "#!/bin/bash" > new_dir/new_file

# %% [markdown]
# Этой командой мы записали строку #!/bin/bash в файл

# %%
# !cat new_dir/new_file
# Out:
# #!/bin/bash

# %% [markdown]
# читаем - действительно

# %%
# !echo "ls" > new_dir/new_file

# %%
# !cat new_dir/new_file
# Out:
# ls

# %% [markdown]
# испльзуя команду повторно, мы перезаписали содержание файла

# %%
# !echo "#!/bin/bash" > new_dir/new_file

# %% [markdown]
# вернули, как было

# %%
# !echo "ls" >> new_dir/new_file

# %%
# !cat new_dir/new_file
# Out:
# #!/bin/bash
# ls

# %% [markdown]
# смогли дописать в конец

# %%
# !./new_dir/new_file
# Out:
# /bin/bash: ./new_dir/new_file: Permission denied

# %% [markdown]
# файл **new_file** уже можно счиать **bash-скриптом**, который при запуске выведет нам содержание папки

# %% [markdown]
# для его запуска в начале нужно допиcать **./** - точка слеш

# %% [markdown]
# попытались, но в ответ нам пишет **/bin/bash: ./new_dir/new_file: Permission denied**
#
# То есть у нас нет разрешения

# %%
# !ls -la new_dir
# Out:
# total 12
# drwxrwxr-x 2 test test 4096 Sep 14 16:46 .
# drwxrwxr-x 4 test test 4096 Sep 14 17:04 ..
# -rw-rw-r-- 1 test test   15 Sep 14 17:00 new_file

# %% [markdown]
# возле нашего файла мы видим это
#
# -rw-rw-r--
#
# Это значит что для владельца файла разрешено rw (read write - читать, писать), для администратора разрешено rw, а для всех остальных только r - чтение.
#
# То есть этот файл разрешено читать и изменять, но ВЫПОЛНЯТЬ пока что нельзя.
#
# Дадим разрешения:

# %%
# !chmod +x new_dir/new_file

# %%
# !ls -la new_dir
# Out:
# total 12
# drwxrwxr-x 2 test test 4096 Sep 14 16:46 .
# drwxrwxr-x 4 test test 4096 Sep 14 17:06 ..
# -rwxrwxr-x 1 test test   15 Sep 14 17:00 new_file

# %% [markdown]
# теперь у нас появились x - разрешения на выполнение

# %%
# !./new_dir/new_file
# Out:
# new_dir  Terminal.ipynb

# %% [markdown]
# теперь наш скрипт запускается

# %% [markdown]
# Можно писать в файл через другую команду **printf** в многострочном режиме:

# %%
# %%bash
#
# printf "
# touch new_file_2
# ls -la
# " >> new_dir/new_file

# %% [markdown]
# Как можно заметить выше, можно вместо восклицательного знака ставить **%%bash** в начале ячейки. Так мы даем понять, что всё содержимое ячейки - команда bash

# %%
# !cat new_dir/new_file
# Out:
# #!/bin/bash
# ls
#
# touch new_file_2
# ls -la

# %% [markdown]
# Чтобы написать скрипт полностью, лучше воспользоваться командой **nano**. Это текстовый редактор.
#
# в терминале пишем
#
# nano script.sh

# %%
# !ls -la
# Out:
# total 212
# drwxrwxr-x 4 test test   4096 Sep 15 14:07 .
# drwxrwxr-x 6 test test   4096 Sep 15 12:10 ..
# -rw-rw-r-- 1 test test   1074 Sep 15 12:07 Gerasim.ipynb
# drwxrwxr-x 2 test test   4096 Sep 15 11:49 .ipynb_checkpoints
# drwxrwxr-x 2 test test   4096 Sep 14 16:46 new_dir
# -rwxrwxr-x 1 test test    433 Sep 15 14:06 script.sh
# -rw-rw-r-- 1 test test 189883 Sep 15 14:03 Terminal.ipynb

# %%
# !cat script.sh
# Out:
# #!/bin/bash
#
# if [[ -n $(ls | grep 'journal.txt') ]]
# then
#         echo 'файл журнала уже есть'
# else
#         echo 'создаем файл журнала'
#         touch journal.txt
# fi
#
# time_now=$(date +%d-%m-%y_%H:%M:%S)
#
# echo 'пишем в файл journal.txt время и содержимое родительской папки'
# echo '' >> journal.txt
# echo $time_now >> journal.txt
# echo $(ls -a) >> journal.txt

# %%
# !./script.sh
# Out:
# создаем файл журнала
# пишем в файл journal.txt время и содержимое родительской папки

# %%
# !ls -la
# Out:
# total 216
# drwxrwxr-x 4 test test   4096 Sep 15 14:07 .
# drwxrwxr-x 6 test test   4096 Sep 15 12:10 ..
# -rw-rw-r-- 1 test test   1074 Sep 15 12:07 Gerasim.ipynb
# drwxrwxr-x 2 test test   4096 Sep 15 11:49 .ipynb_checkpoints
# -rw-rw-r-- 1 test test    102 Sep 15 14:07 journal.txt
# drwxrwxr-x 2 test test   4096 Sep 14 16:46 new_dir
# -rwxrwxr-x 1 test test    433 Sep 15 14:06 script.sh
# -rw-rw-r-- 1 test test 189883 Sep 15 14:03 Terminal.ipynb

# %%
# !cat journal.txt
# Out:
# 15-09-20_14:07:15
# . .. Gerasim.ipynb .ipynb_checkpoints journal.txt new_dir script.sh Terminal.ipynb

# %%
# !./script.sh
# Out:
# файл журнала уже есть
# пишем в файл journal.txt время и содержимое родительской папки

# %%
# !cat journal.txt
# Out:
# 15-09-20_14:07:15
# . .. Gerasim.ipynb .ipynb_checkpoints journal.txt new_dir script.sh Terminal.ipynb
#
# 15-09-20_14:07:36
# . .. Gerasim.ipynb .ipynb_checkpoints journal.txt new_dir script.sh Terminal.ipynb

# %%
# !./script.sh
# Out:
# файл журнала уже есть
# пишем в файл journal.txt время и содержимое родительской папки

# %%
# !./script.sh
# !./script.sh
# Out:
# файл журнала уже есть
# пишем в файл journal.txt время и содержимое родительской папки
# файл журнала уже есть
# пишем в файл journal.txt время и содержимое родительской папки

# %%
# !cat journal.txt
# Out:
# 15-09-20_14:07:15
# . .. Gerasim.ipynb .ipynb_checkpoints journal.txt new_dir script.sh Terminal.ipynb
#
# 15-09-20_14:07:36
# . .. Gerasim.ipynb .ipynb_checkpoints journal.txt new_dir script.sh Terminal.ipynb
#
# 15-09-20_14:08:06
# . .. Gerasim.ipynb .ipynb_checkpoints journal.txt new_dir script.sh Terminal.ipynb
#
# 15-09-20_14:08:09
# . .. Gerasim.ipynb .ipynb_checkpoints journal.txt new_dir script.sh Terminal.ipynb
#
# 15-09-20_14:08:09
# . .. Gerasim.ipynb .ipynb_checkpoints journal.txt new_dir script.sh Terminal.ipynb
